# %% [markdown]
# <a href="https://colab.research.google.com/github/BartTheBartender/ML/blob/asr-llm-tts/hugging-face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pip
# !pip install --upgrade transformers datasets[audio] accelerate scipy

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline, AutoProcessor, AutoModel, AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
from IPython.display import Audio
assert torch.cuda.is_available()
device = "cuda"
torch_dtype = torch.float16

# %%
asr_model_id = "openai/whisper-large-v3"

asr_model = AutoModelForSpeechSeq2Seq.from_pretrained(
    asr_model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
asr_model.to(device)

asr_processor = AutoProcessor.from_pretrained(asr_model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=asr_model,
    tokenizer=asr_processor.tokenizer,
    feature_extractor=asr_processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
    return_timestamps=True,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# ...

# %%
llm_model_id = "speakleash/Bielik-11B-v2.2-Instruct"

tokenizer = AutoTokenizer.from_pretrained(llm_model_id)
llm_model = AutoModelForCausalLM.from_pretrained(llm_model_id, torch_dtype=torch_dtype)

llm_messages = [
    {"role": "system", "content": "Odpowiadaj krótko, precyzyjnie i wyłącznie w języku polskim."},
    {"role": "user", "content": "Jakie mamy pory roku w Polsce?"},
    {"role": "assistant", "content": "W Polsce mamy 4 pory roku: wiosna, lato, jesień i zima."},
    {"role": "user", "content": "Która jest najcieplejsza?"}
]

llm_input_ids = tokenizer.apply_chat_template(llm_messages, return_tensors="pt")

llm_model_inputs = input_ids.to(device)
llm_model.to(device)
# Out:
# ...
# model-00001-of-00005.safetensors:  20%|##        | 1.01G/4.94G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-232c8635f647> in <cell line: 0>()
#       2
#       3 tokenizer = AutoTokenizer.from_pretrained(llm_model_id)
# ----> 4 llm_model = AutoModelForCausalLM.from_pretrained(llm_model_id, torch_dtype=torch_dtype)
#       5
#       6 llm_messages = [
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562         elif type(config) in cls._model_mapping.keys():
#     563             model_class = _get_model_class(config, cls._model_mapping)
# ...

# %%
generated_ids = model.generate(model_inputs, max_new_tokens=1000, do_sample=True)
decoded = tokenizer.batch_decode(generated_ids)
print(decoded[0])

# %%
dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]

result = pipe(sample)
print(result["text"])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:512: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# ...

# %%
result = pipe("./obliczalnosc.mp3")
print(result["text"])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:512: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
#  Rozstrzygalność i czy sioba rozstrzygalność Problem decyzyjny to język L ciągów nad pewnym alfabetem Konkretną instancją problemu jest pytanie Czy jest L gdzie i jest słowem odpowiedź brzmi tak lub nie Mówimy, że problem decyzyjny jest rozstrzygalny Jeżeli istnieje algorytm Maszyna dowolnej instancji tego problemu Znajduje odpowiedź tak lub nie Jeżeli taki algorytm nie istnieje to problem Jest nierozstrzygalny, rozstrzygalny Problem decyzyjny jest częściowo rozstrzygalny Gdy istnieje algorytm Maszyna Turinga bez własności stopu Który poprawnie odpowiada Tylko tak Na koniec nie istnieje A gory poprawnie udzielający Odpowiedzi Odpowiedzi I tak i nie DZIĘKI ZA OBSERWACIE W naszej natury poprawnie odpowiadać

# %%
result = pipe("./dzien-swira.mp3", generate_kwargs={"language": "french", "task": "translate"})
print(result["text"])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:512: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ...
